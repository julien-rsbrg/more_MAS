# %%
# reload the python scripts after modification without having to restart the notebook
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# standard libraries
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import shapely
from typing import Dict
from copy import deepcopy

# from this library
from course_2_path_finding.simple_env import SimpleEnv
from course_2_path_finding.rrt_star import find_path_rrt_star,color_path_and_graph_rrt_star,plot_graph_with_path

# %%
env_bounds = [0,0,100,100]

# Define a continuous environment with objects within
simple_env = SimpleEnv(env_bounds)
simple_env.add_disc(np.array([60, 85]), 35)
simple_env.add_polygon(np.array([[10,10],[10,40],[40,40],[40,10]]))


# # A discrete representation of the env to check that the objects were correctly added
simple_env.plot_objects()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 4
#       1 env_bounds = [0,0,100,100]
#       3 # Define a continuous environment with objects within
# ----> 4 simple_env = SimpleEnv()
#       5 simple_env.add_disc(np.array([60, 85]), 35)
#       6 simple_env.add_polygon(np.array([[10,10],[10,40],[40,40],[40,10]]))
#
# TypeError: SimpleEnv.__init__() missing 1 required positional argument: 'bounds'

# %%
radius = 4
max_nodes = 5000
env_bounds = [0,0,100,100]

start_node_coords = np.array([0,0])
end_node_coords = np.array([100,100]) 

graph,path_edges = find_path_rrt_star(simple_env,max_nodes,radius,start_node_coords,end_node_coords)
plot_graph_with_path(graph, path_edges,title="Example on simple env of RRT*")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 8
#       5 start_node_coords = np.array([0,0])
#       6 end_node_coords = np.array([100,100])
# ----> 8 graph,path_edges = find_path_rrt_star(simple_env,max_nodes,radius,start_node_coords,end_node_coords)
#       9 plot_graph_with_path(graph, path_edges,title="Example on simple env of RRT*")
#
# File c:\Users\jtros\CS\cours\Cours_de_2A\SDMA\more_MAS\course_2_path_finding\rrt_star.py:97, in find_path_rrt_star(env, max_nodes, radius, start_node_coords, end_node_coords)
#      96 def find_path_rrt_star(env, max_nodes, radius, start_node_coords, end_node_coords=None):
# ---> 97     env_bounds = env.bounds
#      99     graph = nx.DiGraph()
#     100     graph.add_node(0, coords=start_node_coords)
#
# AttributeError: 'SimpleEnv' object has no attribute 'bounds'

# %%
next(iter(graph.edges.data()))
# Out:
# (0, 1, {'color': '#1fb451'})

# %%
color_path_and_graph_rrt_star(graph, path_edges)
simple_env.plot_objects(graph=graph,title="Example rrt* result")
